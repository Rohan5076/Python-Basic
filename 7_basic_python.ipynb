# %% [markdown]
# <a href="https://colab.research.google.com/github/krio5076/Python-Basic/blob/main/7_basic_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tuple
#
# 1. Tuple is exactly same as List except that it is immutable. i.e once we creates Tuple
# object, we cannot perform any changes in that object.
# Hence Tuple is Read only version of List.
# 2. If our data is fixed and never changes then we should go for Tuple.
# 3. Insertion Order is preserved
# Duplicates are allowed
# Heterogeneous objects are allowed.
# 4. We can preserve insertion order and we can differentiate duplicate objects by using
# index. Hence index will play very important role in Tuple also.
# 5. Tuple support both +ve and -ve index. +ve index means forward direction (from left to
# right) and -ve index means backward direction (from right to left)
# 6. We can represent Tuple elements within Parenthesis and with comma seperator.

# %%
#parenthesis are optional
t=10,20,30,40
print(t)
print(type(t))
# Out:
# (10, 20, 30, 40)
# <class 'tuple'>

# %% [markdown]
# Q) Which of the following are valid Tuples?
#
# 1) t=()
#
# 2) t=10,20,30,40
#
# 3) t=10
#
# 4)t = (10,)
#
# 5) t=(10,20,30,40)
#
# 6) t = [10,20]
#
# tuple(t)

# %% [markdown]
# # Accessing Elements of Tuple:
# We can access either by index or by slice operator

# %%
# by uing Index:
t=(10,20,30,40,50,60)
print(t[0])#10
print(t[-1])#60
print(t[100])
# Out:
# 10
# 60
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-aca5a090c455> in <module>()
#       3 print(t[0])#10
#       4 print(t[-1])#60
# ----> 5 print(t[100])
#
# IndexError: tuple index out of range

# %%
#by using slice operator
t=(10,20,30,40,50,60)
print(t[2:5])
print(t[2:100])
print(t[::2])
# Out:
# (30, 40, 50)
# (30, 40, 50, 60)
# (10, 30, 50)

# %% [markdown]
# ## **Tuple vs Immutability:**
# Once we creates tuple, we cannot change its content. Hence tuple objects are immutable

# %%
t=(1,2,3)
t[1]=0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-303c5c4eeb59> in <module>()
#       1 t=(1,2,3)
# ----> 2 t[1]=0
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # **Mathematical Operators for Tuple:**
# We can apply + and * operators for tuple

# %%
#1) concatenation operator (+):
t1=(10,20,30)
t2=(40,50,60)
t3=t1+t2
print(t3) #(10,20,30,40,50,60)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
# 2) multiplication operator (+):
t1=(10,20,30)
t2=(40,50,60)
t3=t1+t2
print(t3)#(10,20,30,40,50,60)
# Out:
# (10, 20, 30, 40, 50, 60)

# %% [markdown]
# # Important Functions of Tuple:

# %%
#1. len():
t=(1,2,3,4)
len(t)
# Out:
# 4

# %%
# 2. count(): to return number of occurance of given element in the tuple
t=(1,2,3,4,1,1)
t.count(1)
# Out:
# 3

# %%
# 3. index(): returns index of first occurrence of the given elemnet.
#if the specified element is not availble then we will get value error
t=(10,20,30,40,50,20)
t.index(20)
# Out:
# 1

# %%
#4. sorted(: to sort element based on default natural sorting order)
t=(10,20,30,10,20,5)
t1=(sorted(t))
print(t1)
# Out:
# [5, 10, 10, 20, 20, 30]

# %%
#we can sort according to reverse of default natural sorting order as follows
t12 = sorted(t,reverse=True)
print(t12)
# Out:
# [30, 20, 20, 10, 10, 5]

# %%
#5. min() and max() function:
# these function return min and max values according to default natural sorting order
t=(10,20,30,10,20,30)
print(min(t))#10
print(max(t))#30
# Out:
# 10
# 30

# %% [markdown]
# Q. What do you mean by packing and unpacking of tuple?(explain with the help of code
#
# ans-->
# **packing:** When we create a tuple, we normally assign values to it. This is called "packing" a tuple
#
#  **unpacking:** in Python, we are also allowed to extract the values back into variables. This is called "unpacking":

# %%
fruits = ("apple", "banana", "cherry") #

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# # Tuple Comprehension:
# Tuple Comprehension is not supported by Python.
#
# t = ( x**2 for x in range(1,6))
#
# Here we are not getting tuple object and we are getting generator object.
#
# 1) t= ( x**2 for x in range(1,6))
#
# 2) print(type(t))
#
# 3) for x in t:
#
# 4) print(x

# %%
t=(x**2 for x in range(1,6))
print(type(t))
for x in t:
  print(x)
# Out:
# <class 'generator'>
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# Q. Write a Program to take a Tuple of Numbers from the Keyboard and Print its Sum and Average?

# %%
t=eval(input("Ente tuple of number"))
l=len(t)
sum=0
for x in t:
  sum =sum+x
print("the sum is=",sum)
print("the average is=",sum/l)
# Out:
# Ente tuple of number1,2,3,4
# the sum is= 10
# the average is= 2.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)
