# %% [markdown]
# <a href="https://colab.research.google.com/github/krio5076/Python-Basic/blob/main/15_Basic_Python_Sort_Groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Dataframe.sort_values()
# Pandas sort_values() function sorts a data frame in Ascending or Descending order of passed Column. It’s different than the sorted Python function since it cannot sort a data frame and particular column cannot be selected.

# %%
import pandas as pd
import numpy as np

# %%
data =pd.read_csv("/content/drive/MyDrive/nba.csv")
data.head(10)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2   John Holland  Boston Celtics      30       SG   27    6-5     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# 5   Amir Johnson  Boston Celtics      90       PF   29    6-9     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21    6-8     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25    7-0     238
# 8   Terry Rozier  Boston Celtics      12       PG   22    6-2     190
# 9   Marcus Smart  Boston Celtics      36       PG   22    6-4     220
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
data
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2     John Holland  Boston Celtics      30       SG   27    6-5     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3     203
# 454      Raul Neto       Utah Jazz      25       PG   24    6-1     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26    7-3     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.sort_values("Name",axis=0,ascending=True,na_position='last')
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 152     Aaron Brooks           Chicago Bulls       0       PG   31    6-0
# 356     Aaron Gordon           Orlando Magic       0       PF   20    6-9
# 328   Aaron Harrison       Charlotte Hornets       9       SG   21    6-6
# 404    Adreian Payne  Minnesota Timberwolves      33       PF   25   6-10
# 312       Al Horford           Atlanta Hawks      15        C   30   6-10
# ..               ...                     ...     ...      ...  ...    ...
# 386  Wilson Chandler          Denver Nuggets      21       SF   29    6-8
# 270   Xavier Munford       Memphis Grizzlies      14       PG   24    6-3
# 402      Zach LaVine  Minnesota Timberwolves       8       PG   21    6-5
# 271    Zach Randolph       Memphis Grizzlies      50       PF   34    6-9
# 237    Zaza Pachulia        Dallas Mavericks      27        C   32   6-11
#
#      Weight         College      Salary
# ...

# %%
#sorting data frame by team and then by names
data.sort_values(["Name","Team"],ascending=True,axis=0)
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 152     Aaron Brooks           Chicago Bulls       0       PG   31    6-0
# 356     Aaron Gordon           Orlando Magic       0       PF   20    6-9
# 328   Aaron Harrison       Charlotte Hornets       9       SG   21    6-6
# 404    Adreian Payne  Minnesota Timberwolves      33       PF   25   6-10
# 312       Al Horford           Atlanta Hawks      15        C   30   6-10
# ..               ...                     ...     ...      ...  ...    ...
# 386  Wilson Chandler          Denver Nuggets      21       SF   29    6-8
# 270   Xavier Munford       Memphis Grizzlies      14       PG   24    6-3
# 402      Zach LaVine  Minnesota Timberwolves       8       PG   21    6-5
# 271    Zach Randolph       Memphis Grizzlies      50       PF   34    6-9
# 237    Zaza Pachulia        Dallas Mavericks      27        C   32   6-11
#
#      Weight         College      Salary
# ...

# %% [markdown]
# # **Group By**
# Groupby is a pretty simple concept. We can create a grouping of categories and apply a function to the categories. It’s a simple concept but it’s an extremely valuable technique that’s widely used in data science. In real data science projects, you’ll be dealing with large amounts of data and trying things over and over, so for efficiency, we use Groupby concept. Groupby concept is really important because it’s ability to aggregate data efficiently, both in performance and the amount code is magnificent. Groupby mainly refers to a process involving one or more of the following steps they are:
#
# Splitting : It is a process in which we split data into group by applying some conditions on datasets. Applying : It is a process in which we apply a function to each group independently Combining : It is a process in which we combine different datasets after applying groupby and results into a data structure The following image will help in understanding a process involve in Groupby concept.
#
# Group the unique values from the Team column

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1 Now there’s a bucket for each group
#
#
# ![image.png](data:image/png;base64,...)
#
# 1. Toss the other data into the buckets
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **3. Apply a function on the weight column of each bucket.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Splitting Data into Groups**
# Splitting is a process in which we split data into a group by applying some conditions on datasets. In order to split the data, we apply certain conditions on datasets. In order to split the data, we use groupby() function this function is used to split the data into groups based on some criteria. Pandas objects can be split on any of their axes. The abstract definition of grouping is to provide a mapping of labels to group names. Pandas datasets can be split into any of their objects. There are multiple ways to split data like:
#
# obj.groupby(key)
#
# obj.groupby(key, axis=1)
#
# obj.groupby([key1, key2])
#
# Note :In this we refer to the grouping objects as the keys.
#
# Grouping data with one key: In order to group data with one key, we pass only one key as an argument in groupby function.

# %%
import pandas as pd
data= {"Name":['rahu','dev','nati','reva','deepa','poo'],
       "Age":[45,12,58,63,21,45],
       "Address": ['pune','nanded','mumbai','nagpur','dongri','kalyan'],
       "Qualification" : ["M.B.A",'M.C.A','B.A','B.E','B.B.A','Bsc']}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age Address Qualification
# 0   rahu   45    pune         M.B.A
# 1    dev   12  nanded         M.C.A
# 2   nati   58  mumbai           B.A
# 3   reva   63  nagpur           B.E
# 4  deepa   21  dongri         B.B.A
# 5    poo   45  kalyan           Bsc

# %%
# now we group a data of name using groupby() function.
#using groupby function
#with one key
df.groupby('Name')

# %%
df.groupby('Name').groups
# Out:
# {'deepa': [4], 'dev': [1], 'nati': [2], 'poo': [5], 'rahu': [0], 'reva': [3]}

# %%
df.groupby("Address").groups
# Out:
# {'dongri': [4], 'kalyan': [5], 'mumbai': [2], 'nagpur': [3], 'nanded': [1], 'pune': [0]}

# %%
#importing pandas module
import pandas as pd
#define a dictionery containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
				'Gaurav', 'Anuj', 'Princi', 'Abhi'],
		'Age':[27, 24, 22, 32,
			33, 36, 27, 32],
		'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
				'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
		'Qualification':['Msc', 'MA', 'MCA', 'Phd',
						'B.Tech', 'B.com', 'Msc', 'MA']}
	#convert the dictionery into dataframe
df=pd.DataFrame(data1)
print(df)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
import pandas as pd
gk =df.groupby("Name")
gk.first()
# Out:
#         Age  Address Qualification
# Name
# Abhi     32  Aligarh            MA
# Anuj     24   Kanpur            MA
# Gaurav   33  Jaunpur        B.Tech
# Jai      27   Nagpur           Msc
# Princi   32  Kannuaj           Phd

# %% [markdown]
# # Grouping data with multiple keys :
# In order to group data with multiple keys, we pass multiple keys in groupby function.

# %%
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
#now we group a data of "Name" and "Qualification" together using multiple key in groupby function
#using multiple keys in
#groupby()function
df.groupby(["Name","Age"])

# %%
df.groupby(["Name","Age"]).groups
# Out:
# {('Abhi', 32): [7], ('Anuj', 24): [1], ('Anuj', 36): [5], ('Gaurav', 33): [4], ('Jai', 22): [2], ('Jai', 27): [0], ('Princi', 27): [6], ('Princi', 32): [3]}

# %% [markdown]
# # Grouping data by sorting keys :
# Group keys are sorted by default using the groupby operation. User can pass sort=False for potential speedups.

# %%
import pandas as pd
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
				'Gaurav', 'Anuj', 'Princi', 'Abhi'],
		'Age':[27, 24, 22, 32,
			33, 36, 27, 32], }


df = pd.DataFrame(data1)

df
# Out:
#      Name  Age
# 0     Jai   27
# 1    Anuj   24
# 2     Jai   22
# 3  Princi   32
# 4  Gaurav   33
# 5    Anuj   36
# 6  Princi   27
# 7    Abhi   32

# %%
#Now we apply groupby() without sort
#using groupby function
#without using sort
df.groupby(["Name","Age"])

# %%
df.groupby(["Name","Age"]).sum()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Abhi, 32), (Anuj, 24), (Anuj, 36), (Gaurav, 33), (Jai, 22), (Jai, 27), (Princi, 27), (Princi, 32)]

# %%
df.groupby("Name")["Age"].sum()
# Out:
# Name
# Abhi      32
# Anuj      60
# Gaurav    33
# Jai       49
# Princi    59
# Name: Age, dtype: int64

# %% [markdown]
# # **Applying function to group**
# After splitting a data into a group, we apply a function to each group in order to do that we perform some operation they are:
#
# 1. Aggregation : It is a process in which we compute a summary statistic (or statistics) about each group. For Example, Compute group sums or means
# 2. Transformation : It is a process in which we perform some group-specific computations and return a like-indexed. For Example, Filling NAs within groups with a value derived from each group
# 3. Filtration : It is a process in which we discard some groups, according to a
# * List item
#
# * List item
#
# * List item
# * List item
#
# group-wise computation that evaluates True or False. For Example, Filtering out data based on the group sum or mean

# %% [markdown]
# # Aggregation :
# Aggregation is a process in which we compute a summary statistic about each group. Aggregated function returns a single aggregated value for each group. After splitting a data into groups using groupby function, several aggregation operations can be performed on the grouped data. Code #1: Using aggregation via the aggregate method.

# %%
#importing pandas module
import pandas as pd

#importing numpy as np
import numpy as np

#define a dictionery containing employee data
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
				'Gaurav', 'Anuj', 'Princi', 'Abhi'],
		'Age':[27, 24, 22, 32,
			33, 36, 27, 32],
		'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
				'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
		'Qualification':['Msc', 'MA', 'MCA', 'Phd',
						'B.Tech', 'B.com', 'Msc', 'MA']}
	
# convert the dictionary into dataframe
df=pd.DataFrame(data1)
print(df)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
#perfroming aggregation using
#aggregate method
grp1 =df.groupby("Name")
grp1.aggregate(np.sum)
# Out:
#         Age
# Name
# Abhi     32
# Anuj     60
# Gaurav   33
# Jai      49
# Princi   59
